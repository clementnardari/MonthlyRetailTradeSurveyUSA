# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sqlalchemy as alchemy

year_MRTS=pd.read_excel('mrtssales92-present.xls',sheet_name='2019',skiprows=4,nrows=66,usecols='B:O',index_col=0)
year_MRTS.drop(index='NOT ADJUSTED',axis=0,inplace=True)
year_MRTS.index = year_MRTS.index.str.replace(","," -")
year_MRTS.index = year_MRTS.index.str.replace("and","-")
year_MRTS.index = year_MRTS.index.str.replace("(","")
year_MRTS.index = year_MRTS.index.str.replace(")","")
year_MRTS.index = year_MRTS.index.str.replace("'s","")
year_MRTS.index = year_MRTS.index.str.replace("Retail sales - food services excl motor vehicle - parts - gasoline stations","Retail sales - food services excl mv - p - gs")
year_MRTS=year_MRTS.transpose()
year_MRTS.drop(index='TOTAL',axis=0,inplace=True)
year_MRTS.index = pd.to_datetime(year_MRTS.index)
year_MRTS=year_MRTS.replace({'(S)' : 0})
year_MRTS=year_MRTS.astype('int64')

year_MRTS['Date']=year_MRTS.index
first = year_MRTS.pop('Date')   
year_MRTS.insert(0, 'Date', first)

engine = alchemy.create_engine('mysql+mysqlconnector://root:3RnlvxI1TG!@localhost:3306/mrts', echo=False)
year_MRTS.to_sql(name='MRTS_table', con=engine,index=False, if_exists='append')

L=year_MRTS.columns
# Out:
# C:\Users\cni4\AppData\Local\Temp/ipykernel_26912/2618343124.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   year_MRTS.index = year_MRTS.index.str.replace("(","")
# C:\Users\cni4\AppData\Local\Temp/ipykernel_26912/2618343124.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   year_MRTS.index = year_MRTS.index.str.replace(")","")
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Duplicate entry '2019-01-01 00:00:00' for key 'mrts_table.PRIMARY'
#
# During handling of the above exception, another exception occurred:
#
# IntegrityError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in executemany(self, operation, seq_params)
#     357                 self._executed = stmt
# --> 358                 return self.execute(stmt)
#     359
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     268         try:
# --> 269             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                          buffered=self._buffered,
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     527         except MySQLInterfaceError as exc:
# --> 528             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     529                                              sqlstate=exc.sqlstate)
#
# IntegrityError: 1062 (23000): Duplicate entry '2019-01-01 00:00:00' for key 'mrts_table.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26912/2618343124.py in <module>
#      25
#      26 engine = alchemy.create_engine('mysql+mysqlconnector://root:3RnlvxI1TG!@localhost:3306/mrts', echo=False)
# ---> 27 year_MRTS.to_sql(name='MRTS_table', con=engine,index=False, if_exists='append')
#      28
#      29 L=year_MRTS.columns
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1450             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1451         )
# -> 1452         ret = self._execute_context(
#    1453             dialect,
#    1454             dialect.execution_ctx_cls._init_compiled,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                             break
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#    1753                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     712
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in executemany(self, operation, seq_params)
#     356             if stmt is not None:
#     357                 self._executed = stmt
# --> 358                 return self.execute(stmt)
#     359
#     360         rowcnt = 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# --> 269             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                          buffered=self._buffered,
#     271                                          raw_as_string=self._raw_as_string)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     526                                query_attrs=self._query_attrs)
#     527         except MySQLInterfaceError as exc:
# --> 528             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     529                                              sqlstate=exc.sqlstate)
#     530         except AttributeError:
#
# IntegrityError: (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '2019-01-01 00:00:00' for key 'mrts_table.PRIMARY'
# [SQL: INSERT INTO `MRTS_table` (`Date`, `Retail - food services sales - total`, `Retail sales - food services excl motor vehicle - parts`, `Retail sales - food services excl gasoline stations`, `Retail sales - food services excl mv - p - gs`, `Retail sales - total`, `Retail sales - total excl. motor vehicle - parts dealers`, `GAFO1`, `Motor vehicle - parts dealers`, `Automobile - other motor vehicle dealers`, `Automobile dealers`, `New car dealers`, `Used car dealers`, `Automotive parts - acc. - - tire stores`, `Furniture - home furn - electronics - - appliance stores`, `Furniture - home furnishings stores`, `Furniture stores`, `Home furnishings stores`, `Floor covering stores`, `All other home furnishings stores`, `Electronics - appliance stores`, `Household appliance stores`, `Electronics stores`, `Building mat. - garden equip. - supplies dealers`, `Building mat. - supplies dealers`, `Paint - wallpaper stores`, `Hardware stores`, `Food - beverage stores`, `Grocery stores`, `Supermarkets - other grocery except convenience stores`, `Beer - wine - - liquor stores`, `Health - personal care stores`, `Pharmacies - drug stores`, `Gasoline stations`, `Clothing - clothing access. stores`, `Clothing stores`, `Men clothing stores`, `Women clothing stores`, `Family clothing stores`, `Other clothing stores`, `Shoe stores`, `Jewelry stores`, `Sporting goods - hobby - musical instrument - - book stores`, `Sporting goods stores`, `Hobby - toy - - game stores`, `Book stores`, `General merch-ise stores`, `Department stores`, `Department storesexcl. discount department stores`, `Discount dept. stores`, `Other general merch-ise stores`, `Warehouse clubs - superstores`, `All other gen. merch-ise stores`, `Miscellaneous store retailers`, `Office supplies - stationery - - gift stores`, `Office supplies - stationery stores`, `Gift - novelty - - souvenir stores`, `Used merch-ise stores`, `Nonstore retailers`, `Electronic shopping - mail-order houses`, `Fuel dealers`, `Food services - drinking places`, `Drinking places`, `Restaurants - other eating places`, `Full service restaurants`, `Limited service eating places`) VALUES (%(Date)s, %(Retail - food services sales - total)s, %(Retail sales - food services excl motor vehicle - parts)s, %(Retail sales - food services excl gasoline stations)s, %(Retail sales - food services excl mv - p - gs)s, %(Retail sales - total)s, %(Retail sales - total excl. motor vehicle - parts dealers)s, %(GAFO1)s, %(Motor vehicle - parts dealers)s, %(Automobile - other motor vehicle dealers)s, %(Automobile dealers)s, %(New car dealers)s, %(Used car dealers)s, %(Automotive parts - acc. - - tire stores)s, %(Furniture - home furn - electronics - - appliance stores)s, %(Furniture - home furnishings stores)s, %(Furniture stores)s, %(Home furnishings stores)s, %(Floor covering stores)s, %(All other home furnishings stores)s, %(Electronics - appliance stores)s, %(Household appliance stores)s, %(Electronics stores)s, %(Building mat. - garden equip. - supplies dealers)s, %(Building mat. - supplies dealers)s, %(Paint - wallpaper stores)s, %(Hardware stores)s, %(Food - beverage stores)s, %(Grocery stores)s, %(Supermarkets - other grocery except convenience stores)s, %(Beer - wine - - liquor stores)s, %(Health - personal care stores)s, %(Pharmacies - drug stores)s, %(Gasoline stations)s, %(Clothing - clothing access. stores)s, %(Clothing stores)s, %(Men clothing stores)s, %(Women clothing stores)s, %(Family clothing stores)s, %(Other clothing stores)s, %(Shoe stores)s, %(Jewelry stores)s, %(Sporting goods - hobby - musical instrument - - book stores)s, %(Sporting goods stores)s, %(Hobby - toy - - game stores)s, %(Book stores)s, %(General merch-ise stores)s, %(Department stores)s, %(Department storesexcl. discount department stores)s, %(Discount dept. stores)s, %(Other general merch-ise stores)s, %(Warehouse clubs - superstores)s, %(All other gen. merch-ise stores)s, %(Miscellaneous store retailers)s, %(Office supplies - stationery - - gi ...
c. - - tire stores': 7154, 'Furniture - home furn - electronics - - appliance stores': 15191, 'Furniture - home furnishings stores': 8629, 'Furniture stores': 4616, 'Home furnishings stores': 4013, 'Floor covering stores': 0, 'All other home furnishings stores': 2088, 'Electronics - appliance stores': 6562, 'Household appliance stores': 1177, 'Electronics stores': 5385, 'Building mat. - garden equip. - supplies dealers': 24039, 'Building mat. - supplies dealers': 21061, 'Paint - wallpaper stores': 860, 'Hardware stores': 1910, 'Food - beverage stores': 56898, 'Grocery stores': 51284, 'Supermarkets - other grocery except convenience stores': 49031, 'Beer - wine - - liquor stores': 3916, 'Health - personal care stores': 26772, 'Pharmacies - drug stores': 22372, 'Gasoline stations': 35514, 'Clothing - clothing access. stores': 1 ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
B=()
for i in np.arange(0,len(L),1):
    print('`'+ L[i] + '`  int,')
# Out:
# `Date`  int,
# `Retail - food services sales - total`  int,
# `Retail sales - food services excl motor vehicle - parts`  int,
# `Retail sales - food services excl gasoline stations`  int,
# `Retail sales - food services excl mv - p - gs`  int,
# `Retail sales - total`  int,
# `Retail sales - total excl. motor vehicle - parts dealers`  int,
# `GAFO1`  int,
# `Motor vehicle - parts dealers`  int,
# `Automobile - other motor vehicle dealers`  int,
# `Automobile dealers`  int,
# `New car dealers`  int,
# `Used car dealers`  int,
# `Automotive parts - acc. - - tire stores`  int,
# `Furniture - home furn - electronics - - appliance stores`  int,
# `Furniture - home furnishings stores`  int,
# `Furniture stores`  int,
# `Home furnishings stores`  int,
# `Floor covering stores`  int,
# `All other home furnishings stores`  int,
# `Electronics - appliance stores`  int,
# `Household appliance stores`  int,
# `Electronics stores`  int,
# `Building mat. - garden equip. - supplies dealers`  int,
# `Building mat. - supplies dealers`  int,
# `Paint - wallpaper stores`  int,
# `Hardware stores`  int,
# `Food - beverage stores`  int,
# `Grocery stores`  int,
# `Supermarkets - other grocery except convenience stores`  int,
# `Beer - wine - - liquor stores`  int,
# `Health - personal care stores`  int,
# `Pharmacies - drug stores`  int,
# `Gasoline stations`  int,
# `Clothing - clothing access. stores`  int,
# `Clothing stores`  int,
# `Men clothing stores`  int,
# `Women clothing stores`  int,
# `Family clothing stores`  int,
# `Other clothing stores`  int,
# `Shoe stores`  int,
# `Jewelry stores`  int,
# `Sporting goods - hobby - musical instrument - - book stores`  int,
# `Sporting goods stores`  int,
# `Hobby - toy - - game stores`  int,
# `Book stores`  int,
# `General merch-ise stores`  int,
# `Department stores`  int,
# `Department storesexcl. discount department stores`  int,
# `Discount dept. stores`  int,
# `Other general merch-ise stores`  int,
# `Warehouse clubs - superstores`  int,
# `All other gen. merch-ise stores`  int,
# `Miscellaneous store retailers`  int,
# `Office supplies - stationery - - gift stores`  int,
# `Office supplies - stationery stores`  int,
# `Gift - novelty - - souvenir stores`  int,
# `Used merch-ise stores`  int,
# `Nonstore retailers`  int,
# `Electronic shopping - mail-order houses`  int,
# `Fuel dealers`  int,
# `Food services - drinking places`  int,
# `Drinking places`  int,
# `Restaurants - other eating places`  int,
# `Full service restaurants`  int,
# `Limited service eating places`  int,
